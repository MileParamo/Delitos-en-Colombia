# %% [markdown]
# # Análisis descriptivo de los datos
# ### Integrantes: Oscar Roncancio, Johana Peña, Diego Alfaro, Milena Páramo
#
# #### Descripción escrita de cada variable del dataset
# 1. Id: Un identificador único para cada registro en el dataset.
# 2. Departamento: El nombre del departamento en Colombia donde ocurrió el delito.
# 3. Municipio: El nombre del municipio dentro del departamento donde ocurrió el delito.
# 4. Código DANE: Un código único asignado por el Departamento Administrativo Nacional de Estadística (DANE) para identificar municipios en Colombia.
# 5. Armas Medio: Indica el medio o arma utilizada en el delito.
# 6. Fecha: La fecha en que ocurrió el delito, en formato día/mes/año.
# 7. Genero: El género de la persona involucrada en el delito, ya sea "Femenino" o "Masculino".
# 8. Agrupaciones de edad: La categoría de edad de la persona involucrada en el delito.
# 9. Cantidad Del Delito: El número de veces que ocurrió el delito en el registro.
# 10. Delito: El tipo de delito cometido.
# 11. ICON: Un enlace a una imagen que representa el delito.

# %%
import pandas as pd

# Unión de los archivos y creación del DataFrame

for i in range(1,7):
    df = pd.read_csv(f'data/delitos{i}.csv',encoding='latin1')
    if i == 1:
        df_total = df
    else:
        df_total = pd.concat([df_total, df])

df_total
# Out:
# C:\Users\tlsdz\AppData\Local\Temp\ipykernel_11328\305579552.py:6: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'data/delitos{i}.csv',encoding='latin1')
#              Id Departamento            Municipio  Código DANE  \
# 0             1        Huila          Campoalegre   41132000.0
# 1             2         Meta    San Juan De Arama   50683000.0
# 2             3       Boyacá                Belén   15087000.0
# 3             4     Casanare                 Pore   85263000.0
# 4             5       Caldas                Neira   17486000.0
# ...         ...          ...                  ...          ...
# 201384  5201385      Vichada  Puerto Carreño (Ct)   99001000.0
# 201385  5201386      Vichada        Santa Rosalía   99624000.0
# 201386  5201387      Vichada        Santa Rosalía   99624000.0
# 201387  5201388      Vichada        Santa Rosalía   99624000.0
# ...
